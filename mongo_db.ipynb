# %% [markdown]
# # Data platform design for e-commerce catalog data.
#
# We use  MongoDB (as a NoSQL database) to store data, write queries in mongosh, and export data to a csv file.

# %% [markdown]
# # Contents
# ## 1. Import data into a MongoDB database
# ### 1.1. Create a database called catalog with collections called electronics and upload data from external source
# ### 1.2. Download the catalog.json file
# ### 1.3. Upload data to 'catalog' database
# ### 1.3. List out all the collections in 'catalog'
#
# ## 2. Query data in a MongoDB database
# ### 2.1. Create an index on the field "type"
# ### 2.2. Find the count of laptops
# ### 2.3. Find the count of smartphones with screen size 6
# ### 2.4. Find the average screen size of smartphones
#
# ## 3. Export data from MongoDB

# %% [markdown]
# ## 1. Import data into a MongoDB database
# ### 1.1. Create a database called 'catalog' with collections called 'electronics' and upload data from external source
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.2. Import json file
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.3. Upload data into MonoDG:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.2. List out all the collections in the database catalog:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. Query Data

# %% [markdown]
# ### 2.1. Create an index on the field "type":
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.2. Find the count of laptops:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.3. Find the count of smartphones with size 6:
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.4. Find out the average screen size of smartphones:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.  Export data to a file
#
# Export the fields _id, "type", "model" from the 'electronics' collection into a file named electronics.csv
#
# In the git bash terminal:
#
# mongoexport --db catalog --collection electronics --type=csv --fields _id,type,model --out electronics.csv
#
#
# ![image.png](attachment:image.png)
